# %%
# %matplotlib inline
import cv2
import os
import glob
import matplotlib.pyplot as plt
import scipy.ndimage

os.chdir('..')
os.chdir('Images')
f = open('./list.txt', 'r')
category = f.readline()[:-1]
l = glob.glob('./' + category + '/*')
#rotation angle in degree
img = plt.imread(l[0])

# %%
rotated = scipy.ndimage.rotate(img, 45, mode='nearest', reshape='True')
plt.imshow(rotated)
